# %%
import requests
import json
import pandas as pd

def get_markets(api_key, secret, passphrase):
    url = "https://clob.polymarket.com/markets"
    headers = {
        'Authorization': f'Bearer {api_key}',
        # Add HMAC signature logic here
    }
    response = requests.get(url, headers=headers)
    return response.json()

# %%
# %% [markdown]
# # Fetch all Polymarket markets into a DataFrame

# %% [code]
import requests
import pandas as pd
import time

def fetch_markets(limit=1000, offset=0, closed=None):
    """
    Fetch markets from Polymarket Gamma API.
    Returns list of market dicts.
    """
    base_url = "https://gamma-api.polymarket.com/markets"
    params = {
        "limit": limit,
        "offset": offset
    }
    if closed is not None:
        params["closed"] = str(closed).lower()
    resp = requests.get(base_url, params=params)
    resp.raise_for_status()
    return resp.json()

# %% [code]
# Example: fetch first page
markets_page = fetch_markets(limit=1000, offset=0, closed=False)
len(markets_page)
# Out:
# 500

# %%
# %% [code]
# Loop through pages to build full list (or until some maximum)
all_markets = []
limit = 1000
offset = 0
while True:
    print(f"Fetching offset {offset}")
    page = fetch_markets(limit=limit, offset=offset, closed=False)
    if not page:
        break
    all_markets.extend(page)
    # if fewer than limit returned, no more pages
    if len(page) < limit:
        break
    offset += limit
    # be polite with API
    time.sleep(0.2)

# %% [code]
# Create DataFrame
df = pd.DataFrame(all_markets)
    
# %% [code]
# Select a subset of useful columns, rename if you like
cols = [
    "id",
    "question",
    "lastTradePrice",
    "slug",
    "conditionId",
    "startDate",
    "endDate",
    "volumeNum",
    "liquidityNum",
    "active",
    "closed",
    "endDate"
]
# Some fields may be missing — use .get or fillna
df_sel = df.reindex(columns=cols)
df_sel = df_sel.rename(columns={
    "volumeNum": "volume",
    "liquidityNum": "liquidity"
})

# %% [code]
# Display sorted by volume descending
df_sel = df_sel.sort_values(by=["volume"], ascending=False)
df_sel.head(20)

# %% [markdown]
# ## Further possibilities
# - You can filter by category (e.g., df_sel[df_sel["category"]=="Politics"]).
# - Convert date columns to pandas datetime: `pd.to_datetime(df_sel["startDate"])`.
# - Export to CSV: `df_sel.to_csv("polymarket_markets.csv", index=False)`.
# - For live updates you could re-run the fetch periodically, or use the WebSocket endpoints.
# Out:
# Fetching offset 0
#          id  \
# 303  525362
# 10   516719
# 189  520930
# 98   517014
# 2    516710
# 102  517018
# 100  517016
# 103  517019
# 207  521918
# 8    516716
# 307  525410
# 42   516864
# 185  520630
# 51   516878
# 41   516863
# 99   517015
# 306  525386
# 302  525358
# 50   516877
# 138  517817
#
#                                                                                            question  \
# 303                                               Will George Russell be the 2025 Drivers Champion?
# 10                                                              Russia x Ukraine ceasefire in 2025?
# 189                                                         Jerome Powell out as Fed Chair in 2025?
# 98                          Will The Fantastic Four: First Steps be the top grossing movie of 2025?
# 2                                                                             US recession in 2025?
# 102                                            Will Thunderbolts be the top grossing movie of 2025?
# 100                        Will Captain America: Brave New World be the top grossing movie of 2025?
# 103                                Will How to Train Your Dragon be the top grossing movie of 2025?
# 207  Will UCR hold the most seats in the Chamber of Deputies following the 2025 Argentina election?
# 8                                                   Khamenei out as Supreme Leader of Iran in 2025?
# 307                                         Will the Los Angeles Dodgers win the 2025 World Series?
# 42                                                Will Bitcoin reach $150,000 by December 31, 2025?
# 185                                                               Will China invade Taiwan in 2025?
# 51                                                         Will Ethereum hit $5,000 by December 31?
# 41                                                Will Bitcoin reach $200,000 by December 31, 2025?
# 99                                  Will Jurassic World: Rebirth be the top grossing movie of 2025?
# 306                                           Will the Toronto Blue Jays win the 2025 World Series?
# 302                                               Will Max Verstappen be the 2025 Drivers Champion?
# 50                                                         Will Ethereum hit $6,000 by December 31?
# 138                                                           Will Trump acquire Greenland in 2025?
#
#      lastTradePrice  \
# 303           0.002
# 10            0.140
# 189           0.037
# 98            0.002
# 2             0.040
# 102           0.004
# 100           0.002
# 103           0.002
# 207           0.001
# 8             0.120
# 307           0.800
# 42            0.180
# 185           0.033
# 51            0.483
# 41            0.031
# 99            0.004
# 306           0.201
# 302           0.188
# 50            0.220
# 138           0.022
#
#                                                                                               slug  \
# 303                                               will-george-russell-be-the-2025-drivers-champion
# 10                                                              russia-x-ukraine-ceasefire-in-2025
# 189                                                                will-trump-remove-jerome-powell
# 98                           will-the-fantastic-four-first-steps-be-the-top-grossing-movie-of-2025
# 2                                                                             us-recession-in-2025
# 102                                            will-thunderbolts-be-the-top-grossing-movie-of-2025
# 100                         will-captain-america-new-world-order-be-the-top-grossing-movie-of-2025
# 103                                will-how-to-train-your-dragon-be-the-top-grossing-movie-of-2025
# 207  will-ucr-hold-the-most-seats-in-the-chamber-of-deputies-following-the-2025-argentina-election
# 8                                                   khamenei-out-as-supreme-leader-of-iran-in-2025
# 307                                         will-the-los-angeles-dodgers-win-the-2025-world-series
# 42                                               will-bitcoin-reach-150000-by-december-31-2025-188
# 185                                                               will-china-invade-taiwan-in-2025
# 51                                                   will-ethereum-hit-5000-by-december-31-796-376
# 41                                                   will-bitcoin-reach-200000-by-december-31-2025
# 99                                   will-jurassic-world-rebirth-be-the-top-grossing-movie-of-2025
# 306                                           will-the-toronto-blue-jays-win-the-2025-world-series
# 302                                               will-max-verstappen-be-the-2025-drivers-champion
# 50                                                   will-ethereum-hit-6000-by-december-31-843-315
# 138                                                           will-trump-acquire-greenland-in-2025
#
#                                                             conditionId  \
# 303  0x7e8953cc66f9dabfe80fb0d1a9284bffb7a293f700b21027261fade58a082d73
# 10   0x8ee2f1640386310eb5e7ffa596ba9335f2d324e303d21b0dfea6998874445791
# 189  0x01d5f475cb30704216ae9906d369c0b2991cafec882ab4888a66ff11eb03e569
# 98   0x1cfde498b977cf83dd6a0276fb287de98dbeb79554c61368d074736730883ad8
# 2    0xfa48a99317daef1654d5b03e30557c4222f276657275628d9475e141c64b545d
# 102  0x46fb01da8662e5eb2496b600bbe874d230f05f3e99b382f2791015ef55b464af
# 100  0x2993e8c18922f93787756e02dc262c193b79f05c7b952a0c9656e948f9977c88
# 103  0x22fa7126aad142e3e7cd7dc6ae6669b86e28ff8ae6f07a57e1a05403c8074b5f
# 207  0x937d7afc09f1d2a16a4daa1928798725ba97c809bccac841d0907117dbccceca
# 8    0x1b6f76e5b8587ee896c35847e12d11e75290a8c3934c5952e8a9d6e4c6f03cfa
# 307  0x1073cc3483263763397b853cb095ac8451f7e26b5a94231b5973c14bf6e7a95a
# 42   0x9aa6086535a4b3145e9f7378dd58a7a8c30c4b15bd4fe17eb6990817f5cd3cd9
# 185  0xcb1531b00e984865530f13e4ce35bcbc7d71615af98827b5e9aee2ca2984b626
# 51   0xeeb92ddd77d671d1f9ea1f5727208d1fa91896a6d1f657fdcd7c9d578fe5c46c
# 41   0x4e2887e913cd6e091c9b07b5e4013b24f372453efa6f11a0b0c5f65371729cf4
# 99   0x6e9fda006161184b29a2df3754b5b9c3757f8a2adc1f44291fe9907f8fc6ae97
# 306  0x4c9ccd1404d105968de9b1ff3226fbafdc0b6e402a26bbcad3a84a1b62296783
# 302  0xe3afb091ba0c2bd1d0660ac9256f37e0c7560b02eee15641c6cce6ceb62f3769
# 50   0x9c08beafa73308625ad24e270e44d9edd634585f2424eea8df262a05a2337613
# 138  0x5a2c59ffeb6d19ec30d9a1a689b0a2f50381d442f9a159ab9dfd2a2aae0948bb
#
#                        startDate               endDate        volume  \
# 303     2025-02-26T19:34:12.998Z  2025-12-07T12:00:00Z  2.613836e+07
# 10       2024-12-29T22:51:33.18Z  2025-12-31T12:00:00Z  2.456885e+07
# 189     2025-01-29T23:13:22.244Z  2025-12-31T12:00:00Z  1.061825e+07
# 98    2025-01-02T18:47:24.03753Z  2025-12-31T12:00:00Z  1.038551e+07
# 2       2025-01-08T01:33:54.924Z  2026-02-28T12:00:00Z  9.875202e+06
# 102  2025-01-02T18:49:13.002797Z  2025-12-31T12:00:00Z  9.729959e+06
# 100     2025-01-02T18:47:42.296Z  2025-12-31T12:00:00Z  9.296330e+06
# 103   2025-01-02T18:50:19.06847Z  2025-12-31T12:00:00Z  8.077479e+06
# 207     2025-02-06T00:03:20.627Z  2025-10-26T12:00:00Z  8.073938e+06
# 8       2024-12-29T22:39:48.361Z  2025-12-31T12:00:00Z  7.781774e+06
# 307      2025-02-26T20:10:37.66Z  2025-10-31T12:00:00Z  7.566611e+06
# 42      2024-12-30T22:01:36.925Z  2025-12-31T12:00:00Z  6.817841e+06
# 185     2025-01-29T00:13:22.603Z  2025-12-31T12:00:00Z  6.728264e+06
# 51      2024-12-30T22:07:47.006Z  2025-12-31T12:00:00Z  6.064330e+06
# 41       2024-12-30T22:01:26.81Z  2025-12-31T12:00:00Z  6.010073e+06
# 99   2025-01-02T18:47:34.316137Z  2025-12-31T12:00:00Z  5.525347e+06
# 306     2025-02-26T20:02:08.172Z  2025-10-31T12:00:00Z  5.198789e+06
# 302      2025-02-26T19:32:49.19Z  2025-12-07T12:00:00Z  4.904517e+06
# 50      2024-12-30T22:07:00.605Z  2025-12-31T12:00:00Z  4.537373e+06
# 138  2025-01-07T14:00:25.772267Z  2025-12-31T12:00:00Z  4.487646e+06
#
#         liquidity  active  closed               endDate
# 303  520467.43948    True   False  2025-12-07T12:00:00Z
# 10   393511.29970    True   False  2025-12-31T12:00:00Z
# 189  118398.98956    True   False  2025-12-31T12:00:00Z
# 98   428304.24625    True   False  2025-12-31T12:00:00Z
# 2     90725.18390    True   False  2026-02-28T12:00:00Z
# 102  398693.95846    True   False  2025-12-31T12:00:00Z
# 100  449629.48083    True   False  2025-12-31T12:00:00Z
# 103  463754.97465    True   False  2025-12-31T12:00:00Z
# 207   29283.36379    True   False  2025-10-26T12:00:00Z
# 8     82010.84220    True   False  2025-12-31T12:00:00Z
# 307  187881.50020    True   False  2025-10-31T12:00:00Z
# 42   115969.48810    True   False  2025-12-31T12:00:00Z
# 185  173915.12847    True   False  2025-12-31T12:00:00Z
# 51    67315.44149    True   False  2025-12-31T12:00:00Z
# 41   209278.00758    True   False  2025-12-31T12:00:00Z
# 99   344612.15461    True   False  2025-12-31T12:00:00Z
# 306  194555.42409    True   False  2025-10-31T12:00:00Z
# 302   71078.85132    True   False  2025-12-07T12:00:00Z
# 50    60288.23410    True   False  2025-12-31T12:00:00Z
# 138  125468.07980    True   False  2025-12-31T12:00:00Z

# %%
# List all columns in the dataframe
print(df.columns.tolist())

# Or for a prettier vertical view
df.info()

# See one example record to inspect nested keys
df.iloc[0]
# Out:
# ['id', 'question', 'conditionId', 'slug', 'resolutionSource', 'endDate', 'startDate', 'image', 'icon', 'description', 'outcomes', 'active', 'closed', 'marketMakerAddress', 'createdAt', 'updatedAt', 'new', 'featured', 'submitted_by', 'archived', 'restricted', 'groupItemTitle', 'groupItemThreshold', 'enableOrderBook', 'orderPriceMinTickSize', 'orderMinSize', 'startDateIso', 'volume1wk', 'volume1mo', 'volume1yr', 'umaBond', 'umaReward', 'volume24hrAmm', 'volume1wkAmm', 'volume1moAmm', 'volume1yrAmm', 'volume24hrClob', 'volume1wkClob', 'volume1moClob', 'volume1yrClob', 'volumeAmm', 'volumeClob', 'liquidityAmm', 'liquidityClob', 'negRisk', 'events', 'ready', 'funded', 'cyom', 'competitive', 'pagerDutyNotificationEnabled', 'approved', 'rewardsMinSize', 'rewardsMaxSpread', 'spread', 'oneDayPriceChange', 'oneHourPriceChange', 'oneWeekPriceChange', 'oneMonthPriceChange', 'oneYearPriceChange', 'lastTradePrice', 'bestBid', 'bestAsk', 'clearBookOnStart', 'manualActivation', 'negRiskOther', 'umaResolutionStatuses', 'pendingDeployment', 'deploying', 'rfqEnabled', 'holdingRewardsEnabled', 'feesEnabled', 'liquidity', 'outcomePrices', 'volume', 'resolvedBy', 'questionID', 'volumeNum', 'liquidityNum', 'endDateIso', 'hasReviewedDates', 'volume24hr', 'clobTokenIds', 'acceptingOrders', 'acceptingOrdersTimestamp', 'clobRewards', 'automaticallyActive', 'gameStartTime', 'customLiveness', 'seriesColor', 'showGmpSeries', 'showGmpOutcome', 'negRiskMarketID', 'negRiskRequestID', 'umaResolutionStatus', 'deployingTimestamp']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 96 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            500 non-null    object
#  1   question                      500 non-null    object
#  2   conditionId                   500 non-null    object
#  3   slug                          500 non-null    object
#  4   resolutionSource              483 non-null    object
#  5   endDate                       490 non-null    object
#  6   startDate                     500 non-null    object
#  7   image                         500 non-null    object
#  8   icon                          500 non-null    object
#  9   description                   500 non-null    object
#  10  outcomes                      500 non-null    object
#  11  active                        500 non-null    bool
#  12  closed                        500 non-null    bool
#  13  marketMakerAddress            500 non-null    object
#  14  createdAt                     500 non-null    object
#  15  updatedAt                     500 non-null    object
#  16  new                           500 non-null    bool
#  17  featured                      500 non-null    bool
#  18  submitted_by                  500 non-null    object
#  19  archived                      500 non-null    bool
#  20  restricted                    500 non-null    bool
#  21  groupItemTitle                500 non-null    object
#  22  groupItemThreshold            500 non-null    object
#  23  enableOrderBook               500 non-null    bool
#  24  orderPriceMinTickSize         500 non-null    float64
#  25  orderMinSize                  500 non-null    int64
#  26  startDateIso                  500 non-null    object
#  27  volume1wk                     469 non-null    float64
#  28  volume1mo                     500 non-null    float64
#  29  volume1yr                     500 non-null    float64
#  30  umaBond                       500 non-null    object
#  31  umaReward                     500 non-null    object
#  32  volume24hrAmm                 1 non-null      float64
#  33  volume1wkAmm                  1 non-null      float64
#  34  volume1moAmm                  1 non-null      float64
#  35  volume1yrAmm                  1 non-null      float64
#  36  volume24hrClob                360 non-null    float64
#  37  volume1wkClob                 469 non-null    float64
#  38  volume1moClob                 500 non-null    float64
#  39  volume1yrClob                 500 non-null    float64
#  40  volumeAmm                     1 non-null      float64
#  41  volumeClob                    500 non-null    float64
#  42  liquidityAmm                  1 non-null      float64
#  43  liquidityClob                 500 non-null    float64
#  44  negRisk                       470 non-null    object
#  45  events                        500 non-null    object
#  46  ready                         500 non-null    bool
#  47  funded                        500 non-null    bool
#  48  cyom                          500 non-null    bool
#  49  competitive                   500 non-null    float64
#  50  pagerDutyNotificationEnabled  500 non-null    bool
#  51  approved                      500 non-null    bool
#  52  rewardsMinSize                500 non-null    int64
#  53  rewardsMaxSpread              500 non-null    float64
#  54  spread                        500 non-null    float64
#  55  oneDayPriceChange             333 non-null    float64
#  56  oneHourPriceChange            98 non-null     float64
#  57  oneWeekPriceChange            421 non-null    float64
#  58  oneMonthPriceChange           467 non-null    float64
#  59  oneYearPriceChange            1 non-null      float64
#  60  lastTradePrice                500 non-null    float64
#  61  bestBid                       477 non-null    float64
#  62  bestAsk                       500 non-null    float64
#  63  clearBookOnStart              500 non-null    bool
#  64  manualActivation              500 non-null    bool
#  65  negRiskOther                  500 non-null    bool
#  66  umaResolutionStatuses         500 non-null    object
#  67  pendingDeployment             500 non-null    bool
#  68  deploying                     500 non-null    bool
#  69  rfqEnabled                    500 non-null    bool
#  70  holdingRewardsEnabled         500 non-null    bool
#  71  feesEnabled                   500 non-null    bool
#  72  liquidity                     499 non-null    object
#  73  outcomePrices                 499 non-null    object
#  74  volume                        499 non-null    object
#  75  resolvedBy                    499 non-null    object
#  76  questionID                    499 non-null    object
#  77  volumeNum                     499 non-null    float64
#  78  liquidityNum                  499 non-null    float64
#  79  endDateIso                    489 non-null    object
#  80  hasReviewedDates              499 non-null    object
#  81  volume24hr                    359 non-null    float64
#  82  clobTokenIds                  499 non-null    object
#  83  acceptingOrders               499 non-null    object
#  84  acceptingOrdersTimestamp      499 non-null    object
#  85  clobRewards                   253 non-null    object
#  86  automaticallyActive           499 non-null    object
#  87  gameStartTime                 51 non-null     object
#  88  customLiveness                72 non-null     float64
#  89  seriesColor                   276 non-null    object
#  90  showGmpSeries                 271 non-null    object
#  91  showGmpOutcome                271 non-null    object
#  92  negRiskMarketID               175 non-null    object
#  93  negRiskRequestID              177 non-null    object
#  94  umaResolutionStatus           6 non-null      object
#  95  deployingTimestamp            2 non-null      object
# dtypes: bool(20), float64(31), int64(2), object(43)
# memory usage: 306.8+ KB
# id                                                       502517
# question                         ARCH Will the match be a draw?
# conditionId
# slug                   will-the-match-be-a-draw-romania-ukraine
# resolutionSource
#                                          ...
# showGmpOutcome                                              NaN
# negRiskMarketID                                             NaN
# negRiskRequestID                                            NaN
# umaResolutionStatus                                         NaN
# deployingTimestamp                                          NaN
# Name: 0, Length: 96, dtype: object

# %%
df_sports = df_sel[df_sel["category"].str.lower() == "sports"]

# Sort by volume (descending) and show the top ones
df_sports = df_sports.sort_values(by="volume", ascending=False)
df_sports.reset_index(drop=True, inplace=True)

print(f"Found {len(df_sports)} sports markets.")
pd.set_option("display.max_colwidth", 100)
df_sports.head(20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/development/prediction-markets/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:191, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:234, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File pandas/_libs/index.pyx:242, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File pandas/_libs/index.pyx:134, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'category'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df_sports = df_sel[df_sel["category"].str.lower() == "sports"]
#       3 # Sort by volume (descending) and show the top ones
#       4 df_sports = df_sports.sort_values(by="volume", ascending=False)
#
# File ~/Desktop/development/prediction-markets/lib/python3.12/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/Desktop/development/prediction-markets/lib/python3.12/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'category'

# %%
# Remove duplicated column names (keep first occurrence)
df_sel = df_sel.loc[:, ~df_sel.columns.duplicated()]

# Make sure endDate is in datetime format
df_sel["endDate"] = pd.to_datetime(df_sel["endDate"], errors="coerce")

# Current UTC time (Polymarket timestamps are UTC)
now = pd.Timestamp.utcnow()

# Compute a 20-minute cutoff
cutoff = now + pd.Timedelta(minutes=20000)

# Filter for markets ending within 20 minutes (but not already ended)
df_ending_soon = df_sel[
    (df_sel["endDate"] > now) & (df_sel["endDate"] <= cutoff)
].copy()

# Sort soonest first
df_ending_soon = df_ending_soon.sort_values(by="endDate")

print(f"{len(df_ending_soon)} markets ending within 20 minutes:")
df_ending_soon[["question", "endDate", "volume", "liquidity"]]
# Out:
# 5 markets ending within 20 minutes:
#                                                     question  \
# 434                          Negative GDP growth in Q3 2025?
# 436                         5% GDP contraction in Q3 2025?
# 307  Will the Los Angeles Dodgers win the 2025 World Series?
# 306    Will the Toronto Blue Jays win the 2025 World Series?
# 457       Will any AI score ≥85% on ARC-AGI-2 by November 3?
#
#                       endDate        volume     liquidity
# 434 2025-10-30 12:00:00+00:00  5.223095e+05   50891.78405
# 436 2025-10-30 12:00:00+00:00  3.139119e+05    5229.68446
# 307 2025-10-31 12:00:00+00:00  7.566611e+06  187881.50020
# 306 2025-10-31 12:00:00+00:00  5.198789e+06  194555.42409
# 457 2025-11-03 12:00:00+00:00  1.172277e+05    4486.58339
